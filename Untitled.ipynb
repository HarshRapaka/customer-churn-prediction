# %%
import joblib

model = joblib.load("../models/churn_model.joblib")

model.feature_names_in_
# Out:
# array(['Gender', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure Months', 'Phone Service', 'Multiple Lines',
#        'Internet Service', 'Online Security', 'Online Backup',
#        'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges',
#        'Tenure_Group', 'Charge_to_Tenure', 'Service_Count'], dtype=object)

# %%
from src.predict import predict_churn

predict_churn(sample_customer)
# Out:
# ---------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.predict import predict_churn
#       3 predict_churn(sample_customer)
#
# ModuleNotFoundError: No module named 'src'

# %%
# !python ../src/predict.py
# Out:
# C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.7.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator OneHotEncoder from version 1.7.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator ColumnTransformer from version 1.7.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.7.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Traceback (most recent call last):
#   File "C:\Users\Harsh\Documents\Customer Churn Prediction\src\predict.py", line 39, in <module>
#     result = predict_churn(sample_customer)
#   File "C:\Users\Harsh\Documents\Customer Churn Prediction\src\predict.py", line 8, in predict_churn
#     prob = model.predict_proba(df)[0][1]
#            ~~~~~~~~~~~~~~~~~~~^^^^
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 903, in predict_proba
#     Xt = transform.transform(Xt)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 1101, in transform
#     Xs = self._call_func_on_transformers(
#         X,
#     ...<3 lines>...
#         routed_params=routed_params,
#     )
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 910, in _call_func_on_transformers
#     return Parallel(n_jobs=self.n_jobs)(jobs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 77, in __call__
#     return super().__call__(iterable_with_config)
#            ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ~~~~^^^^^^^^
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 139, in __call__
#     return self.function(*args, **kwargs)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1531, in _transform_one
#     res = transformer.transform(X, **params.transform)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1092, in transform
#     Xt = transform.transform(Xt, **routed_params[name].transform)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 319, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py", line 1062, in transform
#     X = validate_data(
#         self,
#     ...<6 lines>...
#         ensure_all_finite="allow-nan",
#     )
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 2944, in validate_data
#     out = check_array(X, input_name="X", **check_params)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1055, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py", line 839, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\Harsh\anaconda3\Lib\site-packages\pandas\core\generic.py", line 2171, in __array__
#     arr = np.asarray(values, dtype=dtype)
# ValueError: could not convert string to float: 'Female'

# %%
conda install scikit-learn=1.7.2
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Harsh\anaconda3\envs\nlp
#
#   added / updated specs:
#     - scikit-learn=1.7.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     intel-openmp-2025.0.0      |    haa95532_1164         2.1 MB
#     joblib-1.5.3               |  py310haa95532_0         408 KB
#     libhwloc-2.12.1            |default_hfa10c62_1000         2.3 MB
#     libiconv-1.18              |       hc89ec93_0         687 KB
#     libxml2-2.13.9             |       h6201b9f_0         1.5 MB
#     mkl-2025.0.0               |     h5da7b33_930       104.7 MB
#     mkl-service-2.5.2          |  py310h0b37514_0          72 KB
#     mkl_fft-2.1.1              |  py310h300f80d_0         146 KB
#     mkl_random-1.3.0           |  py310ha5e6156_0         245 KB
#     numpy-2.2.5                |  py310h7894be3_2          11 KB
#     numpy-base-2.2.5           |  py310h7794460_2         9.2 MB
#     openssl-3.5.5              |       hbb43b14_0         8.9 MB
#     scikit-learn-1.7.2         |  py310h7f7e138_1         7.4 MB
#     scipy-1.15.3               |  py310h1bbe36f_1        26.0 MB
#     tbb-2022.3.0               |       h90c84d6_0         162 KB
#     tbb-devel-2022.3.0         |       h90c84d6_0         1.1 MB
#     threadpoolctl-3.5.0        |  py310h4442805_1          42 KB
#     ------------------------------------------------------------
#                                            Total:       164.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   icc_rt             pkgs/main/win-64::icc_rt-2022.1.0-h6049295_2
#   intel-openmp       pkgs/main/win-64::intel-openmp-2025.0.0-haa95532_1164
#   joblib             pkgs/main/win-64::joblib-1.5.3-py310haa95532_0
#   libhwloc           pkgs/main/win-64::libhwloc-2.12.1-default_hfa10c62_1000
#   libiconv           pkgs/main/win-64::libiconv-1.18-hc89ec93_0
#   libxml2            pkgs/main/win-64::libxml2-2.13.9-h6201b9f_0
#   mkl                pkgs/main/win-64::mkl-2025.0.0-h5da7b33_930
#   mkl-service        pkgs/main/win-64::mkl-service-2.5.2-py310h0b37514_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-2.1.1-py310h300f80d_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.3.0-py310ha5e6156_0
#   numpy              pkgs/main/win-64::numpy-2.2.5-py310h7894be3_2
#   numpy-base         pkgs/main/win-64::numpy-base-2.2.5-py310h7794460_2
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.7.2-py310h7f7e138_1
#   scipy              pkgs/main/win-64::scipy-1.15.3-py310h1bbe36f_1
#   tbb                pkgs/main/win-64::tbb-2022.3.0-h90c84d6_0
#   tbb-devel          pkgs/main/win-64::tbb-devel-2022.3.0-h90c84d6_0
#   threadpoolctl      pkgs/main/win-64::threadpoolctl-3.5.0-py310h4442805_1
#
# The following packages will be UPDATED:
#
#   openssl                                 3.0.18-h543e019_0 --> 3.5.5-hbb43b14_0
#   vc                                       14.3-h2df5915_10 --> 14.42-haa95532_5
#
#
#
# Downloading and Extracting Packages: ...working...
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
# scipy-1.15.3         | 26.0 MB   |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    |            |   0%
#
#
#
# openssl-3.5.5        | 8.9 MB    |            |   0%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    |            |   0%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    |            |   0%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    |            |   0%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# joblib-1.5.3         | 408 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.3.0     | 245 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2022.3.0         | 162 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-2.1.1        | 146 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.5.2    | 72 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# threadpoolctl-3.5.0  | 42 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.2.5          | 11 KB     |            |   0%
#
# scipy-1.15.3         | 26.0 MB   |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    |            |   0%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    |            |   0%
#
# scipy-1.15.3         | 26.0 MB   |            |   1%
#
#
# numpy-base-2.2.5     | 9.2 MB    |            |   1%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    |            |   1%
#
# scipy-1.15.3         | 26.0 MB   |            |   1%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 1          |   1%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 1          |   2%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 1          |   2%
#
# scipy-1.15.3         | 26.0 MB   | 1          |   1%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 2          |   2%
#
#
#
# openssl-3.5.5        | 8.9 MB    |            |   0%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 3          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 1          |   1%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 1          |   2%
#
# scipy-1.15.3         | 26.0 MB   | 1          |   2%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 4          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 3          |   3%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 5          |   5%
#
# scipy-1.15.3         | 26.0 MB   | 2          |   2%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 4          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 4          |   4%
#
# scipy-1.15.3         | 26.0 MB   | 2          |   3%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 6          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 5          |   5%
# mkl-2025.0.0         | 104.7 MB  |            |   0%
#
# scipy-1.15.3         | 26.0 MB   | 3          |   3%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 6          |   7%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
# scipy-1.15.3         | 26.0 MB   | 3          |   3%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 5          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 7          |   7%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 5          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 6          |   7%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 8          |   8%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
# scipy-1.15.3         | 26.0 MB   | 3          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 7          |   7%
#
# scipy-1.15.3         | 26.0 MB   | 4          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 6          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 8          |   9%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 8          |   8%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
# scipy-1.15.3         | 26.0 MB   | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | 9          |  10%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 8          |   9%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 6          |   7%
#
# scipy-1.15.3         | 26.0 MB   | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #          |  10%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
#
#
# openssl-3.5.5        | 8.9 MB    | 9          |  10%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #          |  11%
#
# scipy-1.15.3         | 26.0 MB   | 5          |   5%
# mkl-2025.0.0         | 104.7 MB  |            |   1%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #1         |  12%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #1         |  12%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 7          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #3         |  13%
#
# scipy-1.15.3         | 26.0 MB   | 5          |   6%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
# scipy-1.15.3         | 26.0 MB   | 6          |   6%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 7          |   8%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #2         |  12%
#
# scipy-1.15.3         | 26.0 MB   | 6          |   7%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #3         |  13%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #3         |  14%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 8          |   9%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
# scipy-1.15.3         | 26.0 MB   | 7          |   7%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 8          |   9%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #3         |  14%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #4         |  15%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #4         |  15%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
# scipy-1.15.3         | 26.0 MB   | 7          |   8%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #5         |  16%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | 9          |  10%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #5         |  15%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
# scipy-1.15.3         | 26.0 MB   | 7          |   8%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #6         |  16%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #          |  10%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #6         |  16%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
# scipy-1.15.3         | 26.0 MB   | 8          |   8%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #6         |  17%
# mkl-2025.0.0         | 104.7 MB  | 1          |   1%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #6         |  17%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #          |  11%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #7         |  18%
#
# scipy-1.15.3         | 26.0 MB   | 8          |   8%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #7         |  18%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #1         |  11%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #8         |  18%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #8         |  19%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #9         |  19%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #1         |  12%
#
# scipy-1.15.3         | 26.0 MB   | 8          |   9%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #9         |  20%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #9         |  20%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #2         |  12%
#
# scipy-1.15.3         | 26.0 MB   | 8          |   9%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##         |  21%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##         |  20%
# mkl-2025.0.0         | 104.7 MB  | 1          |   2%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #2         |  13%
#
# scipy-1.15.3         | 26.0 MB   | 9          |   9%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##1        |  21%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##         |  21%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##2        |  22%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##1        |  21%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
# scipy-1.15.3         | 26.0 MB   | 9          |   9%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #3         |  13%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##3        |  23%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##2        |  22%
#
# scipy-1.15.3         | 26.0 MB   | 9          |  10%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #3         |  14%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##3        |  24%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##2        |  23%
#
# scipy-1.15.3         | 26.0 MB   | 9          |  10%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##4        |  24%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #4         |  14%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##3        |  24%
# mkl-2025.0.0         | 104.7 MB  | 2          |   2%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##5        |  25%
#
# scipy-1.15.3         | 26.0 MB   | 9          |  10%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #4         |  14%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##4        |  24%
#
# scipy-1.15.3         | 26.0 MB   | #          |  10%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##5        |  26%
#
# scipy-1.15.3         | 26.0 MB   | #          |  10%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##4        |  25%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #4         |  15%
#
# scipy-1.15.3         | 26.0 MB   | #          |  11%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##5        |  25%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##6        |  26%
#
# scipy-1.15.3         | 26.0 MB   | #          |  11%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##5        |  26%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##6        |  27%
#
# scipy-1.15.3         | 26.0 MB   | #1         |  11%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #5         |  15%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##6        |  26%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##7        |  27%
#
# scipy-1.15.3         | 26.0 MB   | #1         |  11%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##6        |  27%
#
# scipy-1.15.3         | 26.0 MB   | #1         |  12%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##7        |  28%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #5         |  16%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##7        |  28%
#
# scipy-1.15.3         | 26.0 MB   | #2         |  12%
# mkl-2025.0.0         | 104.7 MB  | 2          |   3%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##8        |  28%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##8        |  28%
#
# scipy-1.15.3         | 26.0 MB   | #2         |  12%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##8        |  29%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #6         |  16%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #2         |  13%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##8        |  29%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##9        |  29%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #3         |  13%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##9        |  29%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #6         |  16%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ##9        |  30%
#
# scipy-1.15.3         | 26.0 MB   | #3         |  14%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ##9        |  30%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###        |  31%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #3         |  14%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###        |  30%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #7         |  17%
#
# scipy-1.15.3         | 26.0 MB   | #4         |  14%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###1       |  31%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###        |  30%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #4         |  15%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #7         |  18%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###1       |  32%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###        |  31%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #4         |  15%
#
# scipy-1.15.3         | 26.0 MB   | #5         |  15%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###1       |  31%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #7         |  18%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###2       |  32%
#
# scipy-1.15.3         | 26.0 MB   | #5         |  16%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###2       |  33%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #8         |  18%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###1       |  32%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #6         |  16%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #8         |  18%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###2       |  32%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
# scipy-1.15.3         | 26.0 MB   | #6         |  17%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###2       |  33%
#
# scipy-1.15.3         | 26.0 MB   | #7         |  17%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #8         |  18%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###3       |  34%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###3       |  33%
#
# scipy-1.15.3         | 26.0 MB   | #7         |  18%
# mkl-2025.0.0         | 104.7 MB  | 3          |   3%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #8         |  19%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###4       |  34%
#
# scipy-1.15.3         | 26.0 MB   | #8         |  18%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###3       |  34%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #9         |  19%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###4       |  35%
#
# scipy-1.15.3         | 26.0 MB   | #8         |  19%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###5       |  36%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###4       |  34%
#
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# scikit-learn-1.7.2   | 7.4 MB    | #9         |  20%
#
# scipy-1.15.3         | 26.0 MB   | #9         |  19%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###6       |  37%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##         |  20%
#
# scipy-1.15.3         | 26.0 MB   | #9         |  20%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###4       |  35%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###7       |  38%
#
# scipy-1.15.3         | 26.0 MB   | ##         |  20%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###5       |  35%
#
# scipy-1.15.3         | 26.0 MB   | ##         |  21%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###8       |  39%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###5       |  35%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ###9       |  40%
#
# scipy-1.15.3         | 26.0 MB   | ##1        |  21%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###5       |  36%
#
# scipy-1.15.3         | 26.0 MB   | ##1        |  22%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####       |  41%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##         |  21%
#
# scipy-1.15.3         | 26.0 MB   | ##2        |  22%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####1      |  42%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###6       |  36%
#
# scipy-1.15.3         | 26.0 MB   | ##2        |  23%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####2      |  42%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
# scipy-1.15.3         | 26.0 MB   | ##3        |  23%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###6       |  36%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####3      |  44%
#
# scipy-1.15.3         | 26.0 MB   | ##4        |  24%
# mkl-2025.0.0         | 104.7 MB  | 3          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##1        |  21%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###6       |  37%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####4      |  45%
#
# scipy-1.15.3         | 26.0 MB   | ##4        |  24%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##1        |  22%
#
# scipy-1.15.3         | 26.0 MB   | ##4        |  25%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###7       |  37%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####5      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##2        |  22%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####6      |  47%
#
# scipy-1.15.3         | 26.0 MB   | ##5        |  26%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###7       |  38%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##2        |  23%
#
# scipy-1.15.3         | 26.0 MB   | ##6        |  26%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####7      |  48%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
# scipy-1.15.3         | 26.0 MB   | ##6        |  27%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####8      |  49%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###8       |  38%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ####9      |  50%
#
# scipy-1.15.3         | 26.0 MB   | ##7        |  27%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###8       |  39%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##3        |  23%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####      |  50%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##3        |  24%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###8       |  39%
#
# scipy-1.15.3         | 26.0 MB   | ##7        |  28%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####1     |  51%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
# scipy-1.15.3         | 26.0 MB   | ##8        |  28%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####1     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##4        |  24%
#
# scipy-1.15.3         | 26.0 MB   | ##9        |  29%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###9       |  40%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####2     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##4        |  24%
#
# scipy-1.15.3         | 26.0 MB   | ##9        |  30%
# mkl-2025.0.0         | 104.7 MB  | 4          |   4%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####3     |  53%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ###9       |  40%
#
# scipy-1.15.3         | 26.0 MB   | ###        |  30%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##4        |  25%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####       |  40%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####3     |  54%
#
# scipy-1.15.3         | 26.0 MB   | ###        |  31%
#
# scipy-1.15.3         | 26.0 MB   | ###1       |  31%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####4     |  54%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####4     |  55%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
# scipy-1.15.3         | 26.0 MB   | ###2       |  32%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####       |  41%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##5        |  25%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####5     |  56%
#
# scipy-1.15.3         | 26.0 MB   | ###3       |  33%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####6     |  56%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
# scipy-1.15.3         | 26.0 MB   | ###3       |  34%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##5        |  26%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####1      |  41%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####7     |  57%
#
# scipy-1.15.3         | 26.0 MB   | ###5       |  35%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####7     |  58%
#
# scipy-1.15.3         | 26.0 MB   | ###5       |  36%
# mkl-2025.0.0         | 104.7 MB  | 4          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####8     |  59%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##5        |  26%
#
# scipy-1.15.3         | 26.0 MB   | ###6       |  36%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #####9     |  60%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####1      |  41%
#
# scipy-1.15.3         | 26.0 MB   | ###7       |  37%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######     |  61%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####1      |  42%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##6        |  26%
#
# scipy-1.15.3         | 26.0 MB   | ###7       |  38%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######1    |  61%
#
# scipy-1.15.3         | 26.0 MB   | ###8       |  39%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
# scipy-1.15.3         | 26.0 MB   | ###9       |  39%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######2    |  62%
#
# scipy-1.15.3         | 26.0 MB   | ###9       |  40%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######2    |  63%
#
# scipy-1.15.3         | 26.0 MB   | ####       |  41%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######3    |  64%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####1      |  42%
#
# scipy-1.15.3         | 26.0 MB   | ####1      |  42%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######4    |  65%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##7        |  27%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####2      |  42%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
# scipy-1.15.3         | 26.0 MB   | ####2      |  42%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######5    |  66%
#
# scipy-1.15.3         | 26.0 MB   | ####2      |  43%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######6    |  67%
#
# scipy-1.15.3         | 26.0 MB   | ####3      |  44%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##8        |  28%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######7    |  68%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####2      |  42%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
# scipy-1.15.3         | 26.0 MB   | ####4      |  44%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######8    |  69%
#
# scipy-1.15.3         | 26.0 MB   | ####5      |  45%
# mkl-2025.0.0         | 104.7 MB  | 5          |   5%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####2      |  43%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ######9    |  70%
#
# scipy-1.15.3         | 26.0 MB   | ####5      |  46%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
# scipy-1.15.3         | 26.0 MB   | ####6      |  47%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######    |  71%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##8        |  29%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####2      |  43%
#
# scipy-1.15.3         | 26.0 MB   | ####7      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##9        |  29%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######1   |  72%
#
# scipy-1.15.3         | 26.0 MB   | ####8      |  48%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######2   |  73%
#
# scipy-1.15.3         | 26.0 MB   | ####9      |  49%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####3      |  43%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #####      |  50%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######3   |  73%
#
# scipy-1.15.3         | 26.0 MB   | #####1     |  51%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #####2     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##9        |  30%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######4   |  74%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####3      |  43%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #####3     |  53%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #####3     |  54%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######4   |  75%
#
# scipy-1.15.3         | 26.0 MB   | #####4     |  55%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####3      |  44%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######5   |  75%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ##9        |  30%
# mkl-2025.0.0         | 104.7 MB  | 5          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####3      |  44%
#
# scipy-1.15.3         | 26.0 MB   | #####5     |  56%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######5   |  76%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #####7     |  58%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######6   |  76%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####4      |  44%
#
# scipy-1.15.3         | 26.0 MB   | #####8     |  59%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###        |  30%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######6   |  77%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####4      |  44%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | ######     |  60%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######7   |  77%
#
# scipy-1.15.3         | 26.0 MB   | ######1    |  61%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####4      |  45%
#
# scipy-1.15.3         | 26.0 MB   | ######3    |  64%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####4      |  45%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######7   |  78%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###        |  31%
#
# scipy-1.15.3         | 26.0 MB   | ######6    |  66%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######8   |  78%
#
# scipy-1.15.3         | 26.0 MB   | ######7    |  68%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####5      |  45%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###1       |  31%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######8   |  79%
#
# scipy-1.15.3         | 26.0 MB   | ######9    |  69%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######9   |  79%
#
# scipy-1.15.3         | 26.0 MB   | #######    |  71%
#
# scipy-1.15.3         | 26.0 MB   | #######1   |  72%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #######9   |  80%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####5      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###1       |  31%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #######3   |  73%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########   |  80%
#
# scipy-1.15.3         | 26.0 MB   | #######4   |  75%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########   |  81%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####5      |  46%
#
# scipy-1.15.3         | 26.0 MB   | #######6   |  77%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########1  |  81%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | #######8   |  79%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###1       |  32%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####5      |  46%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########1  |  82%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | ########   |  80%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########2  |  82%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
# scipy-1.15.3         | 26.0 MB   | ########1  |  82%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########3  |  83%
#
# scipy-1.15.3         | 26.0 MB   | ########3  |  83%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####6      |  46%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########3  |  84%
#
# scipy-1.15.3         | 26.0 MB   | ########5  |  86%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####6      |  46%
#
# scipy-1.15.3         | 26.0 MB   | ########7  |  87%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########4  |  84%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########5  |  85%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####6      |  46%
#
# scipy-1.15.3         | 26.0 MB   | ########8  |  89%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########5  |  86%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####6      |  47%
#
# scipy-1.15.3         | 26.0 MB   | #########  |  90%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########6  |  86%
#
# scipy-1.15.3         | 26.0 MB   | #########1 |  92%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####6      |  47%
#
# scipy-1.15.3         | 26.0 MB   | #########3 |  93%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###2       |  32%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########7  |  87%
#
# scipy-1.15.3         | 26.0 MB   | #########4 |  95%
# mkl-2025.0.0         | 104.7 MB  | 6          |   6%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########7  |  88%
#
# scipy-1.15.3         | 26.0 MB   | #########5 |  96%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####7      |  47%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
# scipy-1.15.3         | 26.0 MB   | #########7 |  98%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
# scipy-1.15.3         | 26.0 MB   | #########8 |  99%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########8  |  89%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####7      |  47%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####7      |  48%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########9  |  89%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###2       |  33%
#
# scipy-1.15.3         | 26.0 MB   | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########9  |  90%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    |            |   1%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####7      |  48%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | 3          |   3%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########  |  90%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###2       |  33%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | 7          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########  |  91%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####8      |  48%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #          |  11%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########  |  91%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #5         |  16%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####8      |  48%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########1 |  91%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ##2        |  23%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########1 |  92%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ##7        |  28%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########2 |  92%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####8      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###3       |  33%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########2 |  93%
# mkl-2025.0.0         | 104.7 MB  | 6          |   7%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ###3       |  34%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####8      |  49%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ####4      |  45%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########3 |  94%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #####      |  51%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########5 |  95%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####8      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###3       |  33%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #####5     |  56%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########6 |  96%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ######1    |  61%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ######6    |  67%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #######3   |  73%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########6 |  97%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####9      |  49%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ########1  |  81%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########7 |  97%
# mkl-2025.0.0         | 104.7 MB  | 7          |   7%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###3       |  34%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ########7  |  87%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ####9      |  50%
# mkl-2025.0.0         | 104.7 MB  | 7          |   8%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | #########7 |  97%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########8 |  98%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | 7          |   8%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########8 |  99%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####      |  50%
# mkl-2025.0.0         | 104.7 MB  | 7          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    |            |   1%
# mkl-2025.0.0         | 104.7 MB  | 7          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | 7          |   7%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###3       |  34%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########9 |  99%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####      |  50%
# mkl-2025.0.0         | 104.7 MB  | 7          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | #4         |  14%
#
#
# numpy-base-2.2.5     | 9.2 MB    | #########9 | 100%
# mkl-2025.0.0         | 104.7 MB  | 8          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ##         |  21%
# mkl-2025.0.0         | 104.7 MB  | 8          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ##9        |  30%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####      |  51%
# mkl-2025.0.0         | 104.7 MB  | 8          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ###7       |  37%
#
#
# numpy-base-2.2.5     | 9.2 MB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | 8          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ####4      |  44%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###4       |  34%
# mkl-2025.0.0         | 104.7 MB  | 8          |   8%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | #####      |  51%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####      |  51%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | 1          |   1%
# mkl-2025.0.0         | 104.7 MB  | 8          |   9%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | #####8     |  58%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | 4          |   4%
# mkl-2025.0.0         | 104.7 MB  | 8          |   9%
# mkl-2025.0.0         | 104.7 MB  | 8          |   9%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ######5    |  65%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | 7          |   7%
# mkl-2025.0.0         | 104.7 MB  | 8          |   9%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | #######2   |  73%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####1     |  51%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ########   |  80%
# mkl-2025.0.0         | 104.7 MB  | 9          |   9%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####1     |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###4       |  34%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #          |  11%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ########7  |  88%
# mkl-2025.0.0         | 104.7 MB  | 9          |   9%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #2         |  13%
# mkl-2025.0.0         | 104.7 MB  | 9          |   9%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | #########4 |  94%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #4         |  15%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####1     |  51%
# mkl-2025.0.0         | 104.7 MB  | 9          |   9%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###4       |  34%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #9         |  19%
# mkl-2025.0.0         | 104.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | 1          |   1%
# mkl-2025.0.0         | 104.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | #1         |  12%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ##2        |  22%
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | ########## | 100%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####1     |  52%
# mkl-2025.0.0         | 104.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ##4        |  25%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ##5        |  26%
# mkl-2025.0.0         | 104.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ###6       |  36%
# mkl-2025.0.0         | 104.7 MB  | #          |  10%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ##8        |  29%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####1     |  52%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ####8      |  48%
# mkl-2025.0.0         | 104.7 MB  | #          |  10%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ###1       |  31%
# mkl-2025.0.0         | 104.7 MB  | #          |  11%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###4       |  35%
#
#
#
#
#
#
# intel-openmp-2025.0. | 2.1 MB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | #          |  11%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####2     |  52%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ###3       |  33%
# mkl-2025.0.0         | 104.7 MB  | #1         |  11%
# mkl-2025.0.0         | 104.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | #####9     |  60%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ###5       |  35%
# mkl-2025.0.0         | 104.7 MB  | #1         |  12%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####2     |  52%
# mkl-2025.0.0         | 104.7 MB  | #1         |  12%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ###9       |  40%
# mkl-2025.0.0         | 104.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ######7    |  67%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ####1      |  42%
# mkl-2025.0.0         | 104.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | #######7   |  77%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###4       |  35%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####2     |  52%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ####3      |  44%
# mkl-2025.0.0         | 104.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ########8  |  89%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | #########7 |  98%
# mkl-2025.0.0         | 104.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ####6      |  46%
# mkl-2025.0.0         | 104.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | 2          |   2%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ####8      |  48%
# mkl-2025.0.0         | 104.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | #3         |  14%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | ##7        |  28%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #####      |  50%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####2     |  53%
# mkl-2025.0.0         | 104.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | ####6      |  47%
# mkl-2025.0.0         | 104.7 MB  | #3         |  14%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #####2     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###5       |  35%
# mkl-2025.0.0         | 104.7 MB  | #3         |  14%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #####4     |  55%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | ######2    |  63%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####2     |  53%
# mkl-2025.0.0         | 104.7 MB  | #4         |  14%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | #########5 |  96%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #####7     |  58%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 687 KB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | #4         |  14%
#
#
#
#
#
#
#
#
#
#
# joblib-1.5.3         | 408 KB    | 3          |   4%
# mkl-2025.0.0         | 104.7 MB  | #4         |  15%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
# joblib-1.5.3         | 408 KB    | ##3        |  24%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #####9     |  60%
# mkl-2025.0.0         | 104.7 MB  | #4         |  15%
#
#
#
#
#
#
#
#
#
#
# joblib-1.5.3         | 408 KB    | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #5         |  15%
# mkl-2025.0.0         | 104.7 MB  | #5         |  16%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ######5    |  65%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####3     |  53%
# mkl-2025.0.0         | 104.7 MB  | #5         |  16%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###5       |  35%
# mkl-2025.0.0         | 104.7 MB  | #6         |  16%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####3     |  54%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #6         |  16%
#
#
#
#
#
#
#
#
#
#
# joblib-1.5.3         | 408 KB    | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###5       |  35%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####3     |  54%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #######3   |  74%
# mkl-2025.0.0         | 104.7 MB  | #6         |  17%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.3.0     | 245 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.3.0     | 245 KB    | #9         |  20%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #######7   |  77%
# mkl-2025.0.0         | 104.7 MB  | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.3.0     | 245 KB    | #######1   |  72%
# mkl-2025.0.0         | 104.7 MB  | #7         |  17%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #######9   |  79%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####4     |  54%
# mkl-2025.0.0         | 104.7 MB  | #7         |  17%
# mkl-2025.0.0         | 104.7 MB  | #7         |  18%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ########1  |  81%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###5       |  36%
# mkl-2025.0.0         | 104.7 MB  | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.3.0     | 245 KB    | ########## | 100%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2022.3.0         | 162 KB    | 9          |  10%
# mkl-2025.0.0         | 104.7 MB  | #8         |  18%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####4     |  54%
# mkl-2025.0.0         | 104.7 MB  | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2022.3.0         | 162 KB    | ###9       |  40%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ########7  |  88%
# mkl-2025.0.0         | 104.7 MB  | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2022.3.0         | 162 KB    | ########9  |  89%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2022.3.0         | 162 KB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | #8         |  19%
# mkl-2025.0.0         | 104.7 MB  | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-2.1.1        | 146 KB    | #          |  11%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #########2 |  92%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #####4     |  54%
# mkl-2025.0.0         | 104.7 MB  | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-2.1.1        | 146 KB    | ######5    |  66%
#
#
#
#
#
#
#
#
# tbb-devel-2022.3.0   | 1.1 MB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | #9         |  19%
#
#
#
#
#
#
#
# libxml2-2.13.9       | 1.5 MB    | #########5 |  95%
#
#
#
# ...
# mkl-2025.0.0         | 104.7 MB  | #####5     |  55%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########  |  91%
# mkl-2025.0.0         | 104.7 MB  | #####5     |  56%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########1 |  92%
# mkl-2025.0.0         | 104.7 MB  | #####6     |  56%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########2 |  93%
# mkl-2025.0.0         | 104.7 MB  | #####6     |  56%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########4 |  95%
# mkl-2025.0.0         | 104.7 MB  | #####6     |  57%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########5 |  96%
# mkl-2025.0.0         | 104.7 MB  | #####6     |  57%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########6 |  97%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########7 |  98%
#
#
#
# openssl-3.5.5        | 8.9 MB    | #########8 |  99%
# mkl-2025.0.0         | 104.7 MB  | #####7     |  57%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ###9       |  40%
# mkl-2025.0.0         | 104.7 MB  | #####7     |  57%
# mkl-2025.0.0         | 104.7 MB  | #####7     |  58%
# mkl-2025.0.0         | 104.7 MB  | #####7     |  58%
# mkl-2025.0.0         | 104.7 MB  | #####8     |  58%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####       |  40%
# mkl-2025.0.0         | 104.7 MB  | #####8     |  58%
# mkl-2025.0.0         | 104.7 MB  | #####8     |  59%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ########## | 100%
#
#
#
# openssl-3.5.5        | 8.9 MB    | ########## | 100%
# mkl-2025.0.0         | 104.7 MB  | #####9     |  59%
# mkl-2025.0.0         | 104.7 MB  | #####9     |  59%
# mkl-2025.0.0         | 104.7 MB  | #####9     |  60%
# mkl-2025.0.0         | 104.7 MB  | #####9     |  60%
# mkl-2025.0.0         | 104.7 MB  | ######     |  60%
# mkl-2025.0.0         | 104.7 MB  | ######     |  61%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####       |  40%
# mkl-2025.0.0         | 104.7 MB  | ######     |  61%
# mkl-2025.0.0         | 104.7 MB  | ######1    |  61%
# mkl-2025.0.0         | 104.7 MB  | ######1    |  62%
# mkl-2025.0.0         | 104.7 MB  | ######1    |  62%
# mkl-2025.0.0         | 104.7 MB  | ######2    |  62%
# mkl-2025.0.0         | 104.7 MB  | ######2    |  63%
# mkl-2025.0.0         | 104.7 MB  | ######2    |  63%
# mkl-2025.0.0         | 104.7 MB  | ######3    |  63%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####       |  41%
# mkl-2025.0.0         | 104.7 MB  | ######3    |  63%
# mkl-2025.0.0         | 104.7 MB  | ######3    |  64%
# mkl-2025.0.0         | 104.7 MB  | ######4    |  64%
# mkl-2025.0.0         | 104.7 MB  | ######4    |  65%
# mkl-2025.0.0         | 104.7 MB  | ######5    |  65%
# mkl-2025.0.0         | 104.7 MB  | ######6    |  66%
# mkl-2025.0.0         | 104.7 MB  | ######6    |  66%
# mkl-2025.0.0         | 104.7 MB  | ######6    |  67%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####       |  41%
# mkl-2025.0.0         | 104.7 MB  | ######7    |  68%
# mkl-2025.0.0         | 104.7 MB  | ######7    |  68%
# mkl-2025.0.0         | 104.7 MB  | ######8    |  68%
# mkl-2025.0.0         | 104.7 MB  | ######8    |  69%
# mkl-2025.0.0         | 104.7 MB  | ######8    |  69%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####1      |  41%
# mkl-2025.0.0         | 104.7 MB  | ######9    |  69%
# mkl-2025.0.0         | 104.7 MB  | ######9    |  69%
# mkl-2025.0.0         | 104.7 MB  | ######9    |  70%
# mkl-2025.0.0         | 104.7 MB  | ######9    |  70%
# mkl-2025.0.0         | 104.7 MB  | #######    |  70%
# mkl-2025.0.0         | 104.7 MB  | #######    |  70%
# mkl-2025.0.0         | 104.7 MB  | #######    |  70%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####1      |  41%
# mkl-2025.0.0         | 104.7 MB  | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #######    |  71%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  71%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  71%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  71%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  72%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####1      |  41%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  72%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  72%
# mkl-2025.0.0         | 104.7 MB  | #######1   |  72%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  72%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  72%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  72%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####1      |  42%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######2   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  73%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  74%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  74%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####1      |  42%
# mkl-2025.0.0         | 104.7 MB  | #######3   |  74%
# mkl-2025.0.0         | 104.7 MB  | #######4   |  74%
# mkl-2025.0.0         | 104.7 MB  | #######4   |  74%
# mkl-2025.0.0         | 104.7 MB  | #######4   |  75%
# mkl-2025.0.0         | 104.7 MB  | #######4   |  75%
# mkl-2025.0.0         | 104.7 MB  | #######5   |  75%
# mkl-2025.0.0         | 104.7 MB  | #######5   |  75%
# mkl-2025.0.0         | 104.7 MB  | #######5   |  76%
# mkl-2025.0.0         | 104.7 MB  | #######5   |  76%
# mkl-2025.0.0         | 104.7 MB  | #######6   |  76%
# mkl-2025.0.0         | 104.7 MB  | #######6   |  76%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####2      |  42%
# mkl-2025.0.0         | 104.7 MB  | #######6   |  77%
# mkl-2025.0.0         | 104.7 MB  | #######6   |  77%
# mkl-2025.0.0         | 104.7 MB  | #######6   |  77%
# mkl-2025.0.0         | 104.7 MB  | #######7   |  77%
# mkl-2025.0.0         | 104.7 MB  | #######7   |  77%
# mkl-2025.0.0         | 104.7 MB  | #######7   |  78%
# mkl-2025.0.0         | 104.7 MB  | #######7   |  78%
# mkl-2025.0.0         | 104.7 MB  | #######8   |  78%
# mkl-2025.0.0         | 104.7 MB  | #######8   |  78%
# mkl-2025.0.0         | 104.7 MB  | #######8   |  79%
# mkl-2025.0.0         | 104.7 MB  | #######9   |  79%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####2      |  42%
# mkl-2025.0.0         | 104.7 MB  | #######9   |  79%
# mkl-2025.0.0         | 104.7 MB  | ########   |  80%
# mkl-2025.0.0         | 104.7 MB  | ########   |  81%
# mkl-2025.0.0         | 104.7 MB  | ########1  |  81%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####2      |  43%
# mkl-2025.0.0         | 104.7 MB  | ########1  |  82%
# mkl-2025.0.0         | 104.7 MB  | ########1  |  82%
# mkl-2025.0.0         | 104.7 MB  | ########2  |  82%
# mkl-2025.0.0         | 104.7 MB  | ########2  |  83%
# mkl-2025.0.0         | 104.7 MB  | ########3  |  83%
# mkl-2025.0.0         | 104.7 MB  | ########3  |  83%
# mkl-2025.0.0         | 104.7 MB  | ########3  |  84%
# mkl-2025.0.0         | 104.7 MB  | ########3  |  84%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####2      |  43%
# mkl-2025.0.0         | 104.7 MB  | ########4  |  84%
# mkl-2025.0.0         | 104.7 MB  | ########4  |  84%
# mkl-2025.0.0         | 104.7 MB  | ########4  |  85%
# mkl-2025.0.0         | 104.7 MB  | ########5  |  85%
# mkl-2025.0.0         | 104.7 MB  | ########5  |  85%
# mkl-2025.0.0         | 104.7 MB  | ########5  |  86%
# mkl-2025.0.0         | 104.7 MB  | ########5  |  86%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####2      |  43%
# mkl-2025.0.0         | 104.7 MB  | ########6  |  86%
# mkl-2025.0.0         | 104.7 MB  | ########6  |  86%
# mkl-2025.0.0         | 104.7 MB  | ########6  |  87%
# mkl-2025.0.0         | 104.7 MB  | ########7  |  87%
# mkl-2025.0.0         | 104.7 MB  | ########7  |  87%
# mkl-2025.0.0         | 104.7 MB  | ########7  |  88%
# mkl-2025.0.0         | 104.7 MB  | ########8  |  88%
# mkl-2025.0.0         | 104.7 MB  | ########8  |  88%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####3      |  43%
# mkl-2025.0.0         | 104.7 MB  | ########8  |  89%
# mkl-2025.0.0         | 104.7 MB  | ########8  |  89%
# mkl-2025.0.0         | 104.7 MB  | ########9  |  89%
# mkl-2025.0.0         | 104.7 MB  | ########9  |  90%
# mkl-2025.0.0         | 104.7 MB  | ########9  |  90%
# mkl-2025.0.0         | 104.7 MB  | #########  |  90%
# mkl-2025.0.0         | 104.7 MB  | #########  |  90%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####3      |  43%
# mkl-2025.0.0         | 104.7 MB  | #########  |  91%
# mkl-2025.0.0         | 104.7 MB  | #########  |  91%
# mkl-2025.0.0         | 104.7 MB  | #########  |  91%
# mkl-2025.0.0         | 104.7 MB  | #########1 |  91%
# mkl-2025.0.0         | 104.7 MB  | #########1 |  91%
# mkl-2025.0.0         | 104.7 MB  | #########1 |  92%
# mkl-2025.0.0         | 104.7 MB  | #########1 |  92%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####3      |  44%
# mkl-2025.0.0         | 104.7 MB  | #########2 |  92%
# mkl-2025.0.0         | 104.7 MB  | #########2 |  92%
# mkl-2025.0.0         | 104.7 MB  | #########2 |  93%
# mkl-2025.0.0         | 104.7 MB  | #########3 |  93%
# mkl-2025.0.0         | 104.7 MB  | #########3 |  93%
# mkl-2025.0.0         | 104.7 MB  | #########3 |  94%
# mkl-2025.0.0         | 104.7 MB  | #########3 |  94%
# mkl-2025.0.0         | 104.7 MB  | #########4 |  94%
# mkl-2025.0.0         | 104.7 MB  | #########4 |  95%
# mkl-2025.0.0         | 104.7 MB  | #########5 |  95%
# mkl-2025.0.0         | 104.7 MB  | #########5 |  95%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####3      |  44%
# mkl-2025.0.0         | 104.7 MB  | #########5 |  96%
# mkl-2025.0.0         | 104.7 MB  | #########6 |  96%
# mkl-2025.0.0         | 104.7 MB  | #########6 |  96%
# mkl-2025.0.0         | 104.7 MB  | #########6 |  97%
# mkl-2025.0.0         | 104.7 MB  | #########7 |  97%
# mkl-2025.0.0         | 104.7 MB  | #########7 |  97%
# mkl-2025.0.0         | 104.7 MB  | #########7 |  98%
# mkl-2025.0.0         | 104.7 MB  | #########8 |  98%
# mkl-2025.0.0         | 104.7 MB  | #########8 |  98%
# mkl-2025.0.0         | 104.7 MB  | #########8 |  99%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####3      |  44%
# mkl-2025.0.0         | 104.7 MB  | #########9 |  99%
# mkl-2025.0.0         | 104.7 MB  | #########9 |  99%
# mkl-2025.0.0         | 104.7 MB  | #########9 | 100%
# mkl-2025.0.0         | 104.7 MB  | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####4      |  44%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####4      |  44%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####4      |  45%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####4      |  45%
# mkl-2025.0.0         | 104.7 MB  | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####5      |  45%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####5      |  45%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####5      |  45%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####5      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####5      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####6      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####6      |  46%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####6      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####6      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####6      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####7      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####7      |  47%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####7      |  48%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####7      |  48%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####8      |  48%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####8      |  48%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####8      |  48%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####8      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####8      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####9      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####9      |  49%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####9      |  50%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####9      |  50%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ####9      |  50%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####      |  50%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####      |  50%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####      |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####      |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####1     |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####1     |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####1     |  51%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####1     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####2     |  52%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####2     |  53%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####2     |  53%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####3     |  53%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####3     |  54%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####4     |  54%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####4     |  55%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####5     |  55%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####6     |  56%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####6     |  57%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####7     |  58%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####8     |  58%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #####8     |  59%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######     |  60%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######1    |  61%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######2    |  62%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######3    |  64%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######4    |  65%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######5    |  66%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######6    |  67%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######7    |  68%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######8    |  69%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ######9    |  70%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######    |  70%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######1   |  71%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######1   |  72%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######2   |  72%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######3   |  73%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######4   |  74%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######5   |  75%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######6   |  77%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######7   |  77%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #######8   |  79%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########1  |  82%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########4  |  84%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########6  |  87%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########8  |  89%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #########1 |  92%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #########4 |  94%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | #########7 |  98%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########## | 100%
#
#
#
#
# scikit-learn-1.7.2   | 7.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
