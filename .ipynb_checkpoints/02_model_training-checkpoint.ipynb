# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/cleaned_telco.csv")
df.head()
# Out:
#    Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0    Male             No      No         No              2           Yes
# 1  Female             No      No        Yes              2           Yes
# 2  Female             No      No        Yes              8           Yes
# 3  Female             No     Yes        Yes             28           Yes
# 4    Male             No      No        Yes             49           Yes
#
#   Multiple Lines Internet Service Online Security Online Backup  ...  \
# 0             No              DSL             Yes           Yes  ...
# 1             No      Fiber optic              No            No  ...
# 2            Yes      Fiber optic              No            No  ...
# 3            Yes      Fiber optic              No            No  ...
# 4            Yes      Fiber optic              No           Yes  ...
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   Monthly Charges Total Charges Churn Label Churn Value  Churn Score  CLTV  \
# 0           53.85        108.15         Yes           1           86  3239
# 1           70.70        151.65         Yes           1           67  2701
# 2           99.65        820.50         Yes           1           86  5372
# 3          104.80       3046.05         Yes           1           84  5003
# 4          103.70       5036.30         Yes           1           89  5340
#
#                     Churn Reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 24 columns]

# %%
y = df["Churn Value"]
X = df.drop(columns=["Churn Value"])

# %%
y.value_counts(normalize=True)
# Out:
# Churn Value
# 0    0.734215
# 1    0.265785
# Name: proportion, dtype: float64

# %%
def tenure_group(x):
    if x <= 12:
        return "Early"
    elif x <= 24:
        return "Mid"
    else:
        return "Long"

X["Tenure_Group"] = X["Tenure Months"].apply(tenure_group)

# %%
X["Charge_to_Tenure"] = X["Monthly Charges"] / (X["Tenure Months"] + 1)

# %%
service_cols = [
    "Online Security",
    "Online Backup",
    "Device Protection",
    "Tech Support",
    "Streaming TV",
    "Streaming Movies"
]

for col in service_cols:
    X[col] = X[col].map({"Yes": 1, "No": 0})

X["Service_Count"] = X[service_cols].sum(axis=1)

# %%
binary_cols = [
    "Partner",
    "Dependents",
    "Phone Service",
    "Paperless Billing",
    "Gender",
    "Senior Citizen"
]

for col in binary_cols:
    X[col] = X[col].map({"Yes": 1, "No": 0})

# %%
X["Gender"] = X["Gender"].map({"Male":1, "Female":0})

# %%
X.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Gender               7032
# Online Security      7032
# Online Backup        7032
# Streaming TV         7032
# Tech Support         7032
# Device Protection    7032
# Streaming Movies     7032
# Churn Reason         5163
# Partner                 0
# Senior Citizen          0
# dtype: int64

# %%
for col in service_cols:
    X[col] = X[col].apply(lambda x: 1 if x == "Yes" else 0)

# %%
X["Gender"] = X["Gender"].map({"Male": 1, "Female": 0})

# %%
X = X.drop(columns=["Churn Reason"])

# %%
X.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Gender              7032
# Senior Citizen         0
# Partner                0
# Dependents             0
# Tenure Months          0
# Phone Service          0
# Multiple Lines         0
# Internet Service       0
# Online Security        0
# Online Backup          0
# dtype: int64

# %%
X["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
X["Gender"] = X["Gender"].str.strip()
X["Gender"] = X["Gender"].map({"Male": 1, "Female": 0})

# %%
X.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Gender              0
# Senior Citizen      0
# Partner             0
# Dependents          0
# Tenure Months       0
# Phone Service       0
# Multiple Lines      0
# Internet Service    0
# Online Security     0
# Online Backup       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
print("Train distribution: ")
print(y_train.value_counts(normalize=True))

print("\nTest Distribution:")
print(y_test.value_counts(normalize=True))
# Out:
# Train distribution:
# Churn Value
# 0    0.734222
# 1    0.265778
# Name: proportion, dtype: float64
#
# Test Distribution:
# Churn Value
# 0    0.734186
# 1    0.265814
# Name: proportion, dtype: float64

# %%
X_train.dtypes
# Out:
# Gender                 int64
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Label           object
# Churn Score            int64
# CLTV                   int64
# dtype: object

# %%
leakage_cols = ["Churn Label", "Churn Score", "CLTV"]

X = X.drop(columns=leakage_cols)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
binary_cols = [
    "Senior Citizen",
    "Partner",
    "Dependents",
    "Phone Service",
    "Paperless Billing"
]

for col in binary_cols:
    X[col] = X[col].apply(lambda x: 1 if x == "Yes" else 0)

# %%
X.dtypes
# Out:
# Gender                 int64
# Senior Citizen         int64
# Partner                int64
# Dependents             int64
# Tenure Months          int64
# Phone Service          int64
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing      int64
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# dtype: object

# %%
num_cols = [
    "Tenure Months",
    "Monthly Charges",
    "Total Charges"
]

# %%
cat_cols = [
    "Multiple Lines",
    "Internet Service",
    "Online Security",
    "Online Backup",
    "Device Protection",
    "Tech Support",
    "Streaming TV",
    "Streaming Movies",
    "Contract",
    "Payment Method",
]

# %%
binary_cols = [
    "Gender",
    "Senior Citizen",
    "Partner",
    "Dependents",
    "Phone Service",
    "Paperless Billing"
]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
        ("bin", "passthrough", binary_cols)
    ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LogisticRegression(max_iter=1000))
    ]
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 pipeline.fit(X_train, y_train)
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\pipeline.py:663, in Pipeline.fit(self, X, y, **params)
#     657     if self._final_estimator != "passthrough":
#     658         last_step_params = self._get_metadata_for_step(
#     659             step_idx=len(self) - 1,
#     660             step_params=routed_params[self.steps[-1][0]],
#     661             all_params=params,
#     662         )
# --> 663         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     665 return self
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\linear_model\_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# -> 1247 X, y = validate_data(
#    1248     self,
#    1249     X,
#    1250     y,
#    1251     accept_sparse="csr",
#    1252     dtype=_dtype,
#    1253     order="C",
#    1254     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1255 )
#    1256 check_classification_targets(y)
#    1257 self.classes_ = np.unique(y)
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~\anaconda3\envs\textS\lib\site-packages\sklearn\utils\_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'No'

# %%
print(X_train.columns)
# Out:
# Index(['Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges'],
#       dtype='object')

# %%
print(X_train.select_dtypes(include="object").columns)
# Out:
# Index(['Senior Citizen', 'Partner', 'Dependents', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method'],
#       dtype='object')

# %%
set(X_train.select_dtypes(include="object").columns) - set(cat_cols)
# Out:
# {'Dependents',
#  'Paperless Billing',
#  'Partner',
#  'Phone Service',
#  'Senior Citizen'}

# %%
numeric_cols = X_train.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_cols = X_train.select_dtypes(include="object").columns.tolist()

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression

# %%
numeric_transformer = Pipeline(
    steps=[
        ("Scaler", StandardScaler())
    ]
)

# %%
categorical_transformer = Pipeline(
    steps=[
        ("onehot", OneHotEncoder(handle_unknown="ignore"))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_cols),
        ("cat", categorical_transformer, categorical_cols)
    ]
)

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LogisticRegression(max_iter=1000))
    ]
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['Gender', 'Tenure Months',
#                                                    'Monthly Charges',
#                                                    'Total Charges']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Senior Citizen', 'Partner',
#                                                    'Dependents',
#                                                    'Phone Service',
#                                                    'Multiple Lines',
#                                                    'Internet Service',
#                                                    'Online Security',
#                                                    'Online Backup',
#                                                    'Device Protection',
#                                                    'Tech Support',
#                                                    'Streaming TV',
#                                                    'Streaming Movies',
#                                                    'Contract',
#                                                    'Paperless Billing',
#                                                    'Payment Method'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)
y_prob = pipeline.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

print("Accuracy: ", accuracy_score(y_test, y_pred))
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("ROC_AUC: ", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy:  0.806680881307747
# Precision:  0.6448863636363636
# Recall:  0.606951871657754
# ROC_AUC:  0.7429725476391383

# %%
y_pred_adjusted = (y_prob > 0.4).astype(int)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print("Accuracy:", accuracy_score(y_test, y_pred_adjusted))
print("Precision:", precision_score(y_test, y_pred_adjusted))
print("Recall:", recall_score(y_test, y_pred_adjusted))
# Out:
# Accuracy: 0.783226723525231
# Precision: 0.576837416481069
# Recall: 0.6925133689839572

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[908, 125],
#        [147, 227]])

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(y_test, y_prob)

# %%
from sklearn.metrics import PrecisionRecallDisplay
PrecisionRecallDisplay.from_predictions(y_test, y_prob)

# %%
LogisticRegression(max_iter=1000, class_weight="balanced")
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
pipeline.named_steps["model"].coef_
# Out:
# array([[-1.94804912e-02, -1.37777750e+00,  1.47352462e-01,
#          6.46640357e-01, -2.14056404e-01, -1.47366445e-01,
#         -3.00709224e-01, -6.07136247e-02,  6.36068803e-01,
#         -9.97491652e-01,  2.30786538e-02, -3.84501503e-01,
#         -3.31411774e-01,  2.30786538e-02, -5.30897283e-02,
#         -3.76393869e-01,  1.84559562e-01, -1.69588542e-01,
#          1.29782907e-01, -1.69588542e-01, -3.21617214e-01,
#          8.87765306e-03, -1.69588542e-01, -2.00711960e-01,
#         -7.32510047e-02, -1.69588542e-01, -1.18583303e-01,
#          1.21987871e-01, -1.69588542e-01, -3.13822179e-01,
#         -1.92555850e-01, -1.69588542e-01,  7.21542332e-04,
#         -1.69786884e-01, -1.69588542e-01, -2.20474230e-02,
#          5.96827422e-01, -2.04691630e-01, -7.53558641e-01,
#         -3.18943409e-01, -4.24794397e-02, -2.15031603e-01,
#         -1.79570530e-01,  1.68381050e-01, -1.35201766e-01]])

# %%
feature_names = pipeline.named_steps["preprocessor"].get_feature_names_out()
coefs = pipeline.named_steps["model"].coef_[0]

coef_df = pd.DataFrame({
    "feature": feature_names,
    "coefficient": coefs
}).sort_values(by="coefficient", ascending=False)

coef_df.head(10)
# Out:
#                                  feature  coefficient
# 3                     num__Total Charges     0.646640
# 8                     cat__Dependents_No     0.636069
# 36          cat__Contract_Month-to-month     0.596827
# 16     cat__Internet Service_Fiber optic     0.184560
# 43  cat__Payment Method_Electronic check     0.168381
# 2                   num__Monthly Charges     0.147352
# 18               cat__Online Security_No     0.129783
# 27                  cat__Tech Support_No     0.121988
# 13  cat__Multiple Lines_No phone service     0.023079
# 10                 cat__Phone Service_No     0.023079

# %%
coef_df.tail(10)
# Out:
#                       feature  coefficient
# 6             cat__Partner_No    -0.300709
# 29      cat__Tech Support_Yes    -0.313822
# 39  cat__Paperless Billing_No    -0.318943
# 20   cat__Online Security_Yes    -0.321617
# 12     cat__Multiple Lines_No    -0.331412
# 15  cat__Internet Service_DSL    -0.376394
# 11     cat__Phone Service_Yes    -0.384502
# 38     cat__Contract_Two year    -0.753559
# 9         cat__Dependents_Yes    -0.997492
# 1          num__Tenure Months    -1.377778
